# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Ice Cream Sales - temperatures.csv')
data
# Out:
#      Temperature  Ice Cream Profits
# 0             39              13.17
# 1             40              11.88
# 2             41              18.82
# 3             42              18.65
# 4             43              17.02
# ..           ...                ...
# 360           99              85.13
# 361           99              87.08
# 362           99              89.29
# 363          101              81.91
# 364          101              85.02
#
# [365 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Temperature        365 non-null    int64
#  1   Ice Cream Profits  365 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 5.8 KB

# %%
# @title Temperature vs Ice Cream Profits

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Temperature']
  ys = series['Ice Cream Profits']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('Temperature', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Temperature')
_ = plt.ylabel('Ice Cream Profits')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.title('The Effect of Temperature on Ice Cream Sales')
sns.lineplot(x=data['Temperature'], y=data['Ice Cream Profits'])
plt.show()

# %% [markdown]
# Data yang digunakan adalah data Temperature and Ice Cream Sales, yang bersumber dari https://www.kaggle.com/datasets/raphaelmanayon/temperature-and-ice-cream-sales, data ini memberikan penjelasan bahwa dengan adanya kenaikan suhu maka penjualan es krim pun ikut meningkat yang dapat diamati melalui line Graph di atas.
